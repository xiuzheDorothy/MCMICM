# %% [markdown]
# # 人口普查数据分析
# 以2010为例

# %%
import xlrd
import pandas as pd
import numpy as np
from math import radians, cos, sin, asin, sqrt
import xlwt
import operator
import copy
from functools import reduce
import sklearn.cluster as sc
import re

# %%
data=pd.read_csv('./ACS_10_5YR_DP02/ACS_10_5YR_DP02_with_ann.csv')

# %%
data
# Out:
#              GEO.id GEO.id2              GEO.display-label  \
# 0                Id     Id2                      Geography
# 1    0500000US21001   21001         Adair County, Kentucky
# 2    0500000US21003   21003         Allen County, Kentucky
# 3    0500000US21005   21005      Anderson County, Kentucky
# 4    0500000US21007   21007       Ballard County, Kentucky
# ..              ...     ...                            ...
# 460  0500000US54101   54101  Webster County, West Virginia
# 461  0500000US54103   54103   Wetzel County, West Virginia
# 462  0500000US54105   54105     Wirt County, West Virginia
# 463  0500000US54107   54107     Wood County, West Virginia
# 464  0500000US54109   54109  Wyoming County, West Virginia
#
#                                            HC01_VC03  \
# 0    Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                               7272
# 2                                               7811
# ...

# %%
data=data.drop(['HC04_VC03'],axis=1)

# %%
data
# Out:
#              GEO.id GEO.id2              GEO.display-label  \
# 0                Id     Id2                      Geography
# 1    0500000US21001   21001         Adair County, Kentucky
# 2    0500000US21003   21003         Allen County, Kentucky
# 3    0500000US21005   21005      Anderson County, Kentucky
# 4    0500000US21007   21007       Ballard County, Kentucky
# ..              ...     ...                            ...
# 460  0500000US54101   54101  Webster County, West Virginia
# 461  0500000US54103   54103   Wetzel County, West Virginia
# 462  0500000US54105   54105     Wirt County, West Virginia
# 463  0500000US54107   54107     Wood County, West Virginia
# 464  0500000US54109   54109  Wyoming County, West Virginia
#
#                                            HC01_VC03  \
# 0    Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                               7272
# 2                                               7811
# ...

# %% [markdown]
# VC01-    人口信息（各年龄段，性别人数，比例，已婚人口比例等。。。）
